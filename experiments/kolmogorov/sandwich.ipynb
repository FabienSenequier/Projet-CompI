# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install git+https://github.com/google/jax-cfd

# !conda env create -f environment.yml

# !conda activate sda

# !pip install -e "/content/drive/MyDrive/FISE 3A/UE_F_Computational Imaging/Project/sda-master/"

# !pip uninstall -y sda

# !pip install "/content/drive/MyDrive/FISE 3A/UE_F_Computational Imaging/Project/sda-master/"
# Out:
# Mounted at /content/drive
# ...
#   Cloning https://github.com/google/jax-cfd to /tmp/pip-req-build-34e7599a
#   Running command git clone --filter=blob:none --quiet https://github.com/google/jax-cfd /tmp/pip-req-build-34e7599a
#   Resolved https://github.com/google/jax-cfd to commit 59f6d415d3abd66ca2c1728396c7622b41d1ac66
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for jax-cfd: filename=jax_cfd-0.2.1-py3-none-any.whl size=215425 sha256=55d98bd0c483776b1de7d12c61f1ba14fea2cb4bf13ecb5a8987437a23d172bf
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gjl7zki6/wheels/07/b6/2a/eb60bc23551a41312658a147557fc2a8214023a695c057687a
# Successfully built jax-cfd
# ...
# /bin/bash: line 1: conda: command not found
# /bin/bash: line 1: conda: command not found
# Obtaining file:///content/drive/MyDrive/FISE%203A/UE_F_Computational%20Imaging/Project/sda-master
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for sda
# ...
# Found existing installation: sda 1.0.0
# ...

# %%
# !pip install zuko

# !pip install POT
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 92.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 72.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 78.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import torch

import os
import sys

experiments_path = r"/content/drive/MyDrive/FISE 3A/UE_F_Computational Imaging/Project/sda-master/experiments"
sys.path.append(experiments_path)

kolmogorov_path = os.path.join(experiments_path, 'kolmogorov')
sys.path.append(kolmogorov_path)

print(sys.path)

# from utils import *
from kolmogorov.utils import *

chain = make_chain()
# Out:
# ['/content', '/env/python', '/usr/lib/python311.zip', '/usr/lib/python3.11', '/usr/lib/python3.11/lib-dynload', '', '/usr/local/lib/python3.11/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.11/dist-packages/IPython/extensions', '/root/.ipython', '/content/drive/MyDrive/FISE 3A/UE_F_Computational Imaging/Project/sda-master/experiments', '/content/drive/MyDrive/FISE 3A/UE_F_Computational Imaging/Project/sda-master/experiments/kolmogorov']

# %%
# !pip install dawgz

# %%
# !python "/content/drive/MyDrive/FISE 3A/UE_F_Computational Imaging/Project/sda-master/experiments/kolmogorov/generate.py"
# Out:
# 2025-03-23 10:47:33.851583: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742726853.894995    1411 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742726853.915848    1411 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 100% 1024/1024 [8:33:00<00:00, 30.06s/it]

# %%
x = np.load(PATH / '/content/drive/MyDrive/FISE 3A/UE_F_Computational Imaging/Project/sda-master/experiments/kolmogorov/data/x_000016.npy')
x = torch.from_numpy(x)
x = chain.coarsen(x[:9], 4)
w = chain.vorticity(x)

draw(w.reshape(3, 3, 64, 64), zoom=4)
# Out:
# <PIL.Image.Image image mode=RGB size=832x832>

# %%
sandwich(w, mirror=True)
# Out:
# <PIL.Image.Image image mode=RGB size=104x104>

# %%
sandwich(0.7 * w + 0.4 * torch.randn_like(w))
# Out:
# <PIL.Image.Image image mode=RGB size=104x104>

# %%
import numpy as np
x = np.load('/content/drive/MyDrive/FISE 3A/UE_F_Computational Imaging/Project/sda-master/experiments/kolmogorov/data/x_000016.npy')
print(x.shape)

import os
os.listdir('/content/drive/MyDrive/FISE 3A/UE_F_Computational Imaging/Project/sda-master/experiments/kolmogorov/data/')  # See all files generated
# Out:
# (64, 2, 256, 256)
# ['test.h5',
#  'train.h5',
#  'valid.h5',
#  'x_000000.npy',
#  'x_000001.npy',
#  'x_000002.npy',
#  'x_000003.npy',
#  'x_000004.npy',
#  'x_000005.npy',
#  'x_000006.npy',
#  'x_000007.npy',
#  'x_000008.npy',
#  'x_000009.npy',
#  'x_000010.npy',
#  'x_000011.npy',
#  'x_000012.npy',
#  'x_000013.npy',
#  'x_000014.npy',
#  'x_000015.npy',
#  'x_000016.npy',
#  'x_000017.npy',
#  'x_000018.npy',
#  'x_000019.npy',
#  'x_000020.npy',
#  'x_000021.npy',
#  'x_000022.npy',
#  'x_000023.npy',
#  'x_000024.npy',
#  'x_000025.npy',
#  'x_000026.npy',
#  'x_000027.npy',
#  'x_000028.npy',
#  'x_000029.npy',
#  'x_000030.npy',
#  'x_000031.npy',
#  'x_000032.npy',
#  'x_000033.npy',
#  'x_000034.npy',
#  'x_000035.npy',
#  'x_000036.npy',
#  'x_000037.npy',
#  'x_000038.npy',
#  'x_000039.npy',
#  'x_000040.npy',
#  'x_000041.npy',
#  'x_000042.npy',
#  'x_000043.npy',
#  'x_000044.npy',
#  'x_000045.npy',
#  'x_000046.npy',
#  'x_000047.npy',
#  'x_000048.npy',
# ...

# %%
# !mkdir -p "/content/drive/MyDrive/FISE 3A/UE_F_Computational Imaging/Project/sda-master/experiments/kolmogorov/data"

# %%
# !mv /content/data/* "/content/drive/MyDrive/FISE 3A/UE_F_Computational Imaging/Project/sda-master/experiments/kolmogorov/data/"

# %%
import os
print(os.listdir("/content/drive/MyDrive/FISE 3A/UE_F_Computational Imaging/Project/sda-master/experiments/kolmogorov/data")[:10])
# Out:
# ['test.h5', 'train.h5', 'valid.h5', 'x_000000.npy', 'x_000001.npy', 'x_000002.npy', 'x_000003.npy', 'x_000004.npy', 'x_000005.npy', 'x_000006.npy']

# %%
# !python "/content/drive/MyDrive/FISE 3A/UE_F_Computational Imaging/Project/sda-master/experiments/kolmogorov/train.py"
# Out:
# 2025-03-23 22:04:50.226683: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742767490.277179    2965 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742767490.293961    2965 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 3
# wandb: You chose "Don't visualize my results"
# ...
