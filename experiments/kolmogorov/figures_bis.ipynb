# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install git+https://github.com/google/jax-cfd
# Out:
# ...
#   Cloning https://github.com/google/jax-cfd to /tmp/pip-req-build-eahpltc1
#   Running command git clone --filter=blob:none --quiet https://github.com/google/jax-cfd /tmp/pip-req-build-eahpltc1
#   Resolved https://github.com/google/jax-cfd to commit 59f6d415d3abd66ca2c1728396c7622b41d1ac66
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !conda env create -f environment.yml
# Out:
# /bin/bash: line 1: conda: command not found

# %%
# !conda activate sda
# Out:
# /bin/bash: line 1: conda: command not found

# %%
# !pip install -e "/content/drive/MyDrive/FISE 3A/UE_F_Computational Imaging/Project/sda-master/"
# Out:
# Obtaining file:///content/drive/MyDrive/FISE%203A/UE_F_Computational%20Imaging/Project/sda-master
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: sda
#     Found existing installation: sda 1.0.0
#     Uninstalling sda-1.0.0:
#       Successfully uninstalled sda-1.0.0
#   Running setup.py develop for sda
# ...

# %%
# Uninstall sda-master.
# !pip uninstall -y sda

# Install sda-master as a traditional package.
# !pip install "/content/drive/MyDrive/FISE 3A/UE_F_Computational Imaging/Project/sda-master/"
# Out:
# Found existing installation: sda 1.0.0
# Uninstalling sda-1.0.0:
#   Successfully uninstalled sda-1.0.0
# Processing ./drive/MyDrive/FISE 3A/UE_F_Computational Imaging/Project/sda-master
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for sda: filename=sda-1.0.0-py3-none-any.whl size=11749 sha256=e2cc5951fbff17ad2814bb6461386f04f6bfa27620ea4cc56e62d9ef16b61f1f
#   Stored in directory: /root/.cache/pip/wheels/3b/f3/64/bc9d517cfbfeff14e928b9439178786fb1aa77669ef9ebb6b6
# Successfully built sda
# ...

# %%
# !pip install zuko

# %%
# !pip install POT

# %%
# %load_ext autoreload
# %autoreload 2
import os
import sys

sda_path = r"/content/drive/MyDrive/FISE 3A/UE_F_Computational Imaging/Project/sda-master/sda"
sys.path.append(sda_path)

print(sys.path)

import h5py
import numpy as np
import torch

experiments_path = r"/content/drive/MyDrive/FISE 3A/UE_F_Computational Imaging/Project/sda-master/experiments"
sys.path.append(experiments_path)

kolmogorov_path = os.path.join(experiments_path, 'kolmogorov')
sys.path.append(kolmogorov_path)

print(sys.path)

from sda.mcs import *
from sda.score import *
from sda.utils import *

# from utils import *
from kolmogorov.utils import *

chain = make_chain()
# Out:
# ['/content', '/env/python', '/usr/lib/python311.zip', '/usr/lib/python3.11', '/usr/lib/python3.11/lib-dynload', '', '/usr/local/lib/python3.11/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.11/dist-packages/IPython/extensions', '/root/.ipython', '/content/drive/MyDrive/FISE 3A/UE_F_Computational Imaging/Project/sda-master/sda']
# ['/content', '/env/python', '/usr/lib/python311.zip', '/usr/lib/python3.11', '/usr/lib/python3.11/lib-dynload', '', '/usr/local/lib/python3.11/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.11/dist-packages/IPython/extensions', '/root/.ipython', '/content/drive/MyDrive/FISE 3A/UE_F_Computational Imaging/Project/sda-master/sda', '/content/drive/MyDrive/FISE 3A/UE_F_Computational Imaging/Project/sda-master/experiments', '/content/drive/MyDrive/FISE 3A/UE_F_Computational Imaging/Project/sda-master/experiments/kolmogorov']

# %% [markdown]
# ## Score network

# %%
# !pip install --upgrade --force-reinstall dawgz>=0.4.0

# %%
# !apt-get install docker.io
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# docker.io is already the newest version (26.1.3-0ubuntu1~22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 29 not upgraded.

# %%
# !pip install dask distributed

# %%
# !pip uninstall dawgz -y

# !pip install git+https://github.com/francois-rozet/dawgz
# Out:
# Found existing installation: dawgz 1.0.3
# Uninstalling dawgz-1.0.3:
#   Successfully uninstalled dawgz-1.0.3
# ...
#   Cloning https://github.com/francois-rozet/dawgz to /tmp/pip-req-build-lqxcc_af
#   Running command git clone --filter=blob:none --quiet https://github.com/francois-rozet/dawgz /tmp/pip-req-build-lqxcc_af
#   Resolved https://github.com/francois-rozet/dawgz to commit 164e03bb2ffb1c1824f66f4230746bd184d5f030
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for dawgz: filename=dawgz-1.0.3-py3-none-any.whl size=15682 sha256=83ebcf42f0cf53b545d830a3a3bee10ea7fc526c462ffea44a86e1bc838e4861
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8ho0l7e7/wheels/ce/e8/df/1f318ea45a63b24e8a9e8bd24262b95d4f3e3a4f08c44f7391
# Successfully built dawgz
# ...

# %%
# %run "/content/drive/MyDrive/FISE 3A/UE_F_Computational Imaging/Project/sda-master/experiments/kolmogorov/generate.py"

# !python r"/content/drive/MyDrive/FISE 3A/UE_F_Computational Imaging/Project/sda-master/experiments/kolmogorov/generate.py"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /content/drive/MyDrive/FISE 3A/UE_F_Computational Imaging/Project/sda-master/experiments/kolmogorov/generate.py in <module>
#      68     #     prune=True,
#      69     #     export='ALL',
# ---> 70     schedule(
#      71         aggregate,
#      72         name='Data generation',
#
# /usr/local/lib/python3.11/dist-packages/dawgz/__init__.py in schedule(backend, prune, quiet, *jobs, **kwargs)
#     129     }
#     130
# --> 131     scheduler = backends.get(backend)(**kwargs)
#     132     scheduler(*jobs, prune=prune)
#     133     scheduler.dump()
#
# TypeError: 'NoneType' object is not callable

# %%
score = load_score(PATH / 'runs/genial-disco-19_a6ynung2/state.pth')  # k=2, width=64
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-c8790b3eeeab> in <cell line: 0>()
# ----> 1 score = load_score(PATH / 'runs/genial-disco-19_a6ynung2/state.pth')  # k=2, width=64
#
# /content/drive/MyDrive/FISE 3A/UE_F_Computational Imaging/Project/sda-master/experiments/kolmogorov/utils.py in load_score(file, device, **kwargs)
#      72
#      73 def load_score(file: Path, device: str = 'cpu', **kwargs) -> nn.Module:
# ---> 74     state = torch.load(file, map_location=device)
#      75     config = load_config(file.parent)
#      76     config.update(kwargs)
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1423         pickle_load_args["encoding"] = "utf-8"
#    1424
# -> 1425     with _open_file_like(f, "rb") as opened_file:
# ...

# %% [markdown]
# ## Extrapolation

# %%
with h5py.File(PATH / 'data/test.h5') as f:
    x_star = torch.from_numpy(f['x'][5, :8])

w = chain.vorticity(x_star)

draw(w, zoom=4).save('x_star_extra_bis.png')
draw(w, zoom=4)

# %%
def A(x):
    return chain.coarsen(x, 4)[..., ::3, :, 4:12, 4:12]

y_star = torch.normal(A(x_star), 1e-2)

w = chain.vorticity(chain.coarsen(x_star, 4)) / 2

mask = np.zeros((1, 8, 16, 16), dtype=bool)
mask[:, ::3, 4:12, 4:12] = True

draw(w, mask, pad=1, zoom=16).save('y_star_extra_bis.png')
draw(w, mask, pad=1, zoom=16)

# %%
sde = VPSDE(
    GaussianScore(
        y_star,
        A=A,
        std=1e-2,
        sde=VPSDE(score, shape=()),
    ),
    shape=x_star.shape,
).cuda()

x = sde.sample((3,), steps=256, corrections=1, tau=0.5).cpu()
w = chain.vorticity(x)

draw(w, zoom=4).save(f'x_sda_extra_bis.png')
draw(w, zoom=4)

# %% [markdown]
# ## Subsampling

# %%
with h5py.File(PATH / 'data/test.h5') as f:
    x_star = torch.from_numpy(f['x'][6, :8])

w = chain.vorticity(x_star)

draw(w, zoom=4).save('x_star_sub_bis.png')
draw(w, zoom=4)

# %%
def A(x):
    return x[..., 7::16, 7::16]

y_star = torch.normal(A(x_star), 1e-1)

w = chain.vorticity(x_star) / 2

mask = np.zeros((8, 64, 64), dtype=bool)
mask[..., 7::16, 7::16] = True

draw(w, mask, zoom=4).save('y_star_sub_bis.png')
draw(w, mask, zoom=4)

# %%
sde = VPSDE(
    GaussianScore(
        y_star,
        A=A,
        std=1e-1,
        sde=VPSDE(score, shape=()),
    ),
    shape=x_star.shape,
).cuda()

x = sde.sample((3,), steps=256, corrections=1, tau=0.5).cpu()
w = chain.vorticity(x)

draw(w, zoom=4).save(f'x_sda_sub_bis.png')
draw(w, zoom=4)
